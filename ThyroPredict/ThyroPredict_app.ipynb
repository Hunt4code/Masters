# %%
import streamlit as st
import numpy as np
import joblib

# Load the trained model
model = joblib.load('final_xgb_model_threshold_0.4.pkl')

st.title("Thyroid Cancer Risk Prediction")

st.write("Enter the patient details to predict the risk of thyroid cancer.")

# User Input Fields
family_history = st.radio("Family History of Thyroid Cancer?", ('Yes', 'No'))
gender = st.radio("Gender", ('Male', 'Female'))
iodine_deficiency = st.radio("Iodine Deficiency?", ('Yes', 'No'))
radiation_exposure = st.radio("Radiation Exposure?", ('Yes', 'No'))
obesity = st.radio("Obesity?", ('Yes', 'No'))
smoking = st.radio("Smoking?", ('Yes', 'No'))
diabetes = st.radio("Diabetes?", ('Yes', 'No'))
age = st.slider("Age", 1, 100, 30)  # Default age = 30

# Convert user input to numerical format
def preprocess_input(family_history, gender, iodine_deficiency, radiation_exposure, obesity, smoking, diabetes, age):
    return np.array([[
        1 if family_history == 'Yes' else 0,
        1 if gender == 'Male' else 0,
        1 if iodine_deficiency == 'Yes' else 0,
        1 if radiation_exposure == 'Yes' else 0,
        1 if obesity == 'Yes' else 0,
        1 if smoking == 'Yes' else 0,
        1 if diabetes == 'Yes' else 0,
        age
    ]])

# Predict function
def predict_thyroid_risk(patient_data):
    prob_malignant = model.predict_proba(patient_data)[:, 1]
    threshold = 0.3  # Adjusted for better recall
    prediction = (prob_malignant > threshold).astype(int)
    return "Malignant" if prediction[0] == 1 else "Benign"

# Button to make predictions
if st.button("Predict"):
    patient_data = preprocess_input(family_history, gender, iodine_deficiency, radiation_exposure, obesity, smoking, diabetes, age)
    result = predict_thyroid_risk(patient_data)
    st.subheader(f"Prediction: {result}")
# Out:
# 2025-02-27 14:37:09.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 14:37:09.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
